# %%
pip install jupyter_plotly_dash
# Out:
# Requirement already satisfied: jupyter_plotly_dash in /opt/anaconda3/lib/python3.8/site-packages (0.4.2)
# Requirement already satisfied: dpd-components in /opt/anaconda3/lib/python3.8/site-packages (from jupyter_plotly_dash) (0.1.0)
# Requirement already satisfied: django-plotly-dash in /opt/anaconda3/lib/python3.8/site-packages (from jupyter_plotly_dash) (1.4.2)
# Requirement already satisfied: aiohttp in /opt/anaconda3/lib/python3.8/site-packages (from jupyter_plotly_dash) (3.6.2)
# Requirement already satisfied: dpd-static-support in /opt/anaconda3/lib/python3.8/site-packages (from jupyter_plotly_dash) (0.0.5)
# Requirement already satisfied: django-bootstrap4 in /opt/anaconda3/lib/python3.8/site-packages (from jupyter_plotly_dash) (2.2.0)
# Requirement already satisfied: jupyter in /opt/anaconda3/lib/python3.8/site-packages (from jupyter_plotly_dash) (1.0.0)
# Requirement already satisfied: nbserverproxy in /opt/anaconda3/lib/python3.8/site-packages (from jupyter_plotly_dash) (0.8.8)
# Requirement already satisfied: plotly in /opt/anaconda3/lib/python3.8/site-packages (from django-plotly-dash->jupyter_plotly_dash) (4.9.0)
# Requirement already satisfied: Django>=2.2 in /opt/anaconda3/lib/python3.8/site-packages (from django-plotly-dash->jupyter_plotly_dash) (3.1.1)
# Requirement already satisfied: Flask>=1.0.2 in /opt/anaconda3/lib/python3.8/site-packages (from django-plotly-dash->jupyter_plotly_dash) (1.1.2)
# Requirement already satisfied: dash-html-components in /opt/anaconda3/lib/python3.8/site-packages (from django-plotly-dash->jupyter_plotly_dash) (1.1.1)
# Requirement already satisfied: dash-renderer in /opt/anaconda3/lib/python3.8/site-packages (from django-plotly-dash->jupyter_plotly_dash) (1.8.1)
# Requirement already satisfied: dash-core-components in /opt/anaconda3/lib/python3.8/site-packages (from django-plotly-dash->jupyter_plotly_dash) (1.12.1)
# Requirement already satisfied: dash>=1.11 in /opt/anaconda3/lib/python3.8/site-packages (from django-plotly-dash->jupyter_plotly_dash) (1.16.1)
# Requirement already satisfied: multidict<5.0,>=4.5 in /opt/anaconda3/lib/python3.8/site-packages (from aiohttp->jupyter_plotly_dash) (4.7.6)
# Requirement already satisfied: chardet<4.0,>=2.0 in /opt/anaconda3/lib/python3.8/site-packages (from aiohttp->jupyter_plotly_dash) (3.0.4)
# Requirement already satisfied: attrs>=17.3.0 in /opt/anaconda3/lib/python3.8/site-packages (from aiohttp->jupyter_plotly_dash) (19.3.0)
# Requirement already satisfied: async-timeout<4.0,>=3.0 in /opt/anaconda3/lib/python3.8/site-packages (from aiohttp->jupyter_plotly_dash) (3.0.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/anaconda3/lib/python3.8/site-packages (from aiohttp->jupyter_plotly_dash) (1.5.1)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.8.0 in /opt/anaconda3/lib/python3.8/site-packages (from django-bootstrap4->jupyter_plotly_dash) (4.9.1)
# Requirement already satisfied: ipykernel in /opt/anaconda3/lib/python3.8/site-packages (from jupyter->jupyter_plotly_dash) (5.3.2)
# Requirement already satisfied: nbconvert in /opt/anaconda3/lib/python3.8/site-packages (from jupyter->jupyter_plotly_dash) (5.6.1)
# Requirement already satisfied: ipywidgets in /opt/anaconda3/lib/python3.8/site-packages (from jupyter->jupyter_plotly_dash) (7.5.1)
# Requirement already satisfied: qtconsole in /opt/anaconda3/lib/python3.8/site-packages (from jupyter->jupyter_plotly_dash) (4.7.5)
# Requirement already satisfied: jupyter-console in /opt/anaconda3/lib/python3.8/site-packages (from jupyter->jupyter_plotly_dash) (6.1.0)
# Requirement already satisfied: notebook in /opt/anaconda3/lib/python3.8/site-packages (from jupyter->jupyter_plotly_dash) (6.0.3)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.8/site-packages (from plotly->django-plotly-dash->jupyter_plotly_dash) (1.15.0)
# Requirement already satisfied: retrying>=1.3.3 in /opt/anaconda3/lib/python3.8/site-packages (from plotly->django-plotly-dash->jupyter_plotly_dash) (1.3.3)
# Requirement already satisfied: asgiref~=3.2.10 in /opt/anaconda3/lib/python3.8/site-packages (from Django>=2.2->django-plotly-dash->jupyter_plotly_dash) (3.2.10)
# Requirement already satisfied: pytz in /opt/anaconda3/lib/python3.8/site-packages (from Django>=2.2->django-plotly-dash->jupyter_plotly_dash) (2020.1)
# Requirement already satisfied: sqlparse>=0.2.2 in /opt/anaconda3/lib/python3.8/site-packages (from Django>=2.2->django-plotly-dash->jupyter_plotly_dash) (0.3.1)
# Requirement already satisfied: click>=5.1 in /opt/anaconda3/lib/python3.8/site-packages (from Flask>=1.0.2->django-plotly-dash->jupyter_plotly_dash) (7.1.2)
# Requirement already satisfied: Jinja2>=2.10.1 in /opt/anaconda3/lib/python3.8/site-packages (from Flask>=1.0.2->django-plotly-dash->jupyter_plotly_dash) (2.11.2)
# Requirement already satisfied: Werkzeug>=0.15 in /opt/anaconda3/lib/python3.8/site-packages (from Flask>=1.0.2->django-plotly-dash->jupyter_plotly_dash) (1.0.1)
# Requirement already satisfied: itsdangerous>=0.24 in /opt/anaconda3/lib/python3.8/site-packages (from Flask>=1.0.2->django-plotly-dash->jupyter_plotly_dash) (1.1.0)
# Requirement already satisfied: flask-compress in /opt/anaconda3/lib/python3.8/site-packages (from dash>=1.11->django-plotly-dash->jupyter_plotly_dash) (1.5.0)
# Requirement already satisfied: dash-table==4.10.1 in /opt/anaconda3/lib/python3.8/site-packages (from dash>=1.11->django-plotly-dash->jupyter_plotly_dash) (4.10.1)
# Requirement already satisfied: future in /opt/anaconda3/lib/python3.8/site-packages (from dash>=1.11->django-plotly-dash->jupyter_plotly_dash) (0.18.2)
# Requirement already satisfied: idna>=2.0 in /opt/anaconda3/lib/python3.8/site-packages (from yarl<2.0,>=1.0->aiohttp->jupyter_plotly_dash) (2.10)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/lib/python3.8/site-packages (from beautifulsoup4<5.0.0,>=4.8.0->django-bootstrap4->jupyter_plotly_dash) (2.0.1)
# Requirement already satisfied: tornado>=4.2 in /opt/anaconda3/lib/python3.8/site-packages (from ipykernel->jupyter->jupyter_plotly_dash) (6.0.4)
# Requirement already satisfied: traitlets>=4.1.0 in /opt/anaconda3/lib/python3.8/site-packages (from ipykernel->jupyter->jupyter_plotly_dash) (4.3.3)
# Requirement already satisfied: ipython>=5.0.0 in /opt/anaconda3/lib/python3.8/site-packages (from ipykernel->jupyter->jupyter_plotly_dash) (7.16.1)
# Requirement already satisfied: jupyter-client in /opt/anaconda3/lib/python3.8/site-packages (from ipykernel->jupyter->jupyter_plotly_dash) (6.1.6)
# Requirement already satisfied: appnope; platform_system == "Darwin" in /opt/anaconda3/lib/python3.8/site-packages (from ipykernel->jupyter->jupyter_plotly_dash) (0.1.0)
# Requirement already satisfied: pygments in /opt/anaconda3/lib/python3.8/site-packages (from nbconvert->jupyter->jupyter_plotly_dash) (2.6.1)
# Requirement already satisfied: defusedxml in /opt/anaconda3/lib/python3.8/site-packages (from nbconvert->jupyter->jupyter_plotly_dash) (0.6.0)
# Requirement already satisfied: bleach in /opt/anaconda3/lib/python3.8/site-packages (from nbconvert->jupyter->jupyter_plotly_dash) (3.1.5)
# Requirement already satisfied: testpath in /opt/anaconda3/lib/python3.8/site-packages (from nbconvert->jupyter->jupyter_plotly_dash) (0.4.4)
# Requirement already satisfied: entrypoints>=0.2.2 in /opt/anaconda3/lib/python3.8/site-packages (from nbconvert->jupyter->jupyter_plotly_dash) (0.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in /opt/anaconda3/lib/python3.8/site-packages (from nbconvert->jupyter->jupyter_plotly_dash) (0.8.4)
# Requirement already satisfied: jupyter-core in /opt/anaconda3/lib/python3.8/site-packages (from nbconvert->jupyter->jupyter_plotly_dash) (4.6.3)
# Requirement already satisfied: nbformat>=4.4 in /opt/anaconda3/lib/python3.8/site-packages (from nbconvert->jupyter->jupyter_plotly_dash) (5.0.7)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/anaconda3/lib/python3.8/site-packages (from nbconvert->jupyter->jupyter_plotly_dash) (1.4.2)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /opt/anaconda3/lib/python3.8/site-packages (from ipywidgets->jupyter->jupyter_plotly_dash) (3.5.1)
# Requirement already satisfied: qtpy in /opt/anaconda3/lib/python3.8/site-packages (from qtconsole->jupyter->jupyter_plotly_dash) (1.9.0)
# Requirement already satisfied: pyzmq>=17.1 in /opt/anaconda3/lib/python3.8/site-packages (from qtconsole->jupyter->jupyter_plotly_dash) (19.0.1)
# Requirement already satisfied: ipython-genutils in /opt/anaconda3/lib/python3.8/site-packages (from qtconsole->jupyter->jupyter_plotly_dash) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /opt/anaconda3/lib/python3.8/site-packages (from jupyter-console->jupyter->jupyter_plotly_dash) (3.0.5)
# Requirement already satisfied: prometheus-client in /opt/anaconda3/lib/python3.8/site-packages (from notebook->jupyter->jupyter_plotly_dash) (0.8.0)
# Requirement already satisfied: Send2Trash in /opt/anaconda3/lib/python3.8/site-packages (from notebook->jupyter->jupyter_plotly_dash) (1.5.0)
# Requirement already satisfied: terminado>=0.8.1 in /opt/anaconda3/lib/python3.8/site-packages (from notebook->jupyter->jupyter_plotly_dash) (0.8.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/anaconda3/lib/python3.8/site-packages (from Jinja2>=2.10.1->Flask>=1.0.2->django-plotly-dash->jupyter_plotly_dash) (1.1.1)
# Requirement already satisfied: brotli in /opt/anaconda3/lib/python3.8/site-packages (from flask-compress->dash>=1.11->django-plotly-dash->jupyter_plotly_dash) (1.0.9)
# Requirement already satisfied: decorator in /opt/anaconda3/lib/python3.8/site-packages (from traitlets>=4.1.0->ipykernel->jupyter->jupyter_plotly_dash) (4.4.2)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /opt/anaconda3/lib/python3.8/site-packages (from ipython>=5.0.0->ipykernel->jupyter->jupyter_plotly_dash) (4.8.0)
# Requirement already satisfied: setuptools>=18.5 in /opt/anaconda3/lib/python3.8/site-packages (from ipython>=5.0.0->ipykernel->jupyter->jupyter_plotly_dash) (49.2.0.post20200714)
# Requirement already satisfied: jedi>=0.10 in /opt/anaconda3/lib/python3.8/site-packages (from ipython>=5.0.0->ipykernel->jupyter->jupyter_plotly_dash) (0.17.1)
# Requirement already satisfied: backcall in /opt/anaconda3/lib/python3.8/site-packages (from ipython>=5.0.0->ipykernel->jupyter->jupyter_plotly_dash) (0.2.0)
# Requirement already satisfied: pickleshare in /opt/anaconda3/lib/python3.8/site-packages (from ipython>=5.0.0->ipykernel->jupyter->jupyter_plotly_dash) (0.7.5)
# Requirement already satisfied: python-dateutil>=2.1 in /opt/anaconda3/lib/python3.8/site-packages (from jupyter-client->ipykernel->jupyter->jupyter_plotly_dash) (2.8.1)
# Requirement already satisfied: webencodings in /opt/anaconda3/lib/python3.8/site-packages (from bleach->nbconvert->jupyter->jupyter_plotly_dash) (0.5.1)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.8/site-packages (from bleach->nbconvert->jupyter->jupyter_plotly_dash) (20.4)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /opt/anaconda3/lib/python3.8/site-packages (from nbformat>=4.4->nbconvert->jupyter->jupyter_plotly_dash) (3.2.0)
# Requirement already satisfied: wcwidth in /opt/anaconda3/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->jupyter-console->jupyter->jupyter_plotly_dash) (0.2.5)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/anaconda3/lib/python3.8/site-packages (from pexpect; sys_platform != "win32"->ipython>=5.0.0->ipykernel->jupyter->jupyter_plotly_dash) (0.6.0)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /opt/anaconda3/lib/python3.8/site-packages (from jedi>=0.10->ipython>=5.0.0->ipykernel->jupyter->jupyter_plotly_dash) (0.7.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/anaconda3/lib/python3.8/site-packages (from packaging->bleach->nbconvert->jupyter->jupyter_plotly_dash) (2.4.7)
# Requirement already satisfied: pyrsistent>=0.14.0 in /opt/anaconda3/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert->jupyter->jupyter_plotly_dash) (0.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install dash-html-components
# Out:
# Requirement already satisfied: dash-html-components in /opt/anaconda3/lib/python3.8/site-packages (1.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install dash-core-components
# Out:
# Requirement already satisfied: dash-core-components in /opt/anaconda3/lib/python3.8/site-packages (1.12.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
import pandas as pd
import plotly.graph_objs as go
from dash.dependencies import Input, Output
from keras.models import load_model
from sklearn.preprocessing import MinMaxScaler
import numpy as np
app = dash.Dash()
server = app.server
scaler=MinMaxScaler(feature_range=(0,1))
df_nse = pd.read_csv("./NSE-TATA.csv")
df_nse["Date"]=pd.to_datetime(df_nse.Date,format="%Y-%m-%d")
df_nse.index=df_nse['Date']
data=df_nse.sort_index(ascending=True,axis=0)
new_data=pd.DataFrame(index=range(0,len(df_nse)),columns=['Date','Close'])
for i in range(0,len(data)):
    new_data["Date"][i]=data['Date'][i]
    new_data["Close"][i]=data["Close"][i]
new_data.index=new_data.Date
new_data.drop("Date",axis=1,inplace=True)
dataset=new_data.values
train=dataset[0:987,:]
valid=dataset[987:,:]
scaler=MinMaxScaler(feature_range=(0,1))
scaled_data=scaler.fit_transform(dataset)
x_train,y_train=[],[]
for i in range(60,len(train)):
    x_train.append(scaled_data[i-60:i,0])
    y_train.append(scaled_data[i,0])
    
x_train,y_train=np.array(x_train),np.array(y_train)
x_train=np.reshape(x_train,(x_train.shape[0],x_train.shape[1],1))
model=load_model("saved_lstm_model.h5")
inputs=new_data[len(new_data)-len(valid)-60:].values
inputs=inputs.reshape(-1,1)
inputs=scaler.transform(inputs)
X_test=[]
for i in range(60,inputs.shape[0]):
    X_test.append(inputs[i-60:i,0])
X_test=np.array(X_test)
X_test=np.reshape(X_test,(X_test.shape[0],X_test.shape[1],1))
closing_price=model.predict(X_test)
closing_price=scaler.inverse_transform(closing_price)
train=new_data[:987]
valid=new_data[987:]
valid['Predictions']=closing_price
df= pd.read_csv("./stock_data.csv")
app.layout = html.Div([
   
    html.H1("Stock Price Analysis Dashboard", style={"textAlign": "center"}),
   
    dcc.Tabs(id="tabs", children=[
       
        dcc.Tab(label='NSE-TATAGLOBAL Stock Data',children=[
            html.Div([
                html.H2("Actual closing price",style={"textAlign": "center"}),
                dcc.Graph(
                    id="Actual Data",
                    figure={
                        "data":[
                            go.Scatter(
                                x=train.index,
                                y=valid["Close"],
                                mode='markers'
                            )
                        ],
                        "layout":go.Layout(
                            title='scatter plot',
                            xaxis={'title':'Date'},
                            yaxis={'title':'Closing Rate'}
                        )
                    }
                ),
                html.H2("LSTM Predicted closing price",style={"textAlign": "center"}),
                dcc.Graph(
                    id="Predicted Data",
                    figure={
                        "data":[
                            go.Scatter(
                                x=valid.index,
                                y=valid["Predictions"],
                                mode='markers'
                            )
                        ],
                        "layout":go.Layout(
                            title='scatter plot',
                            xaxis={'title':'Date'},
                            yaxis={'title':'Closing Rate'}
                        )
                    }
                )                
            ])                
        ]),
        dcc.Tab(label='Facebook Stock Data', children=[
            html.Div([
                html.H1("Facebook Stocks High vs Lows", 
                        style={'textAlign': 'center'}),
              
                dcc.Dropdown(id='my-dropdown',
                             options=[{'label': 'Tesla', 'value': 'TSLA'},
                                      {'label': 'Apple','value': 'AAPL'}, 
                                      {'label': 'Facebook', 'value': 'FB'}, 
                                      {'label': 'Microsoft','value': 'MSFT'}], 
                             multi=True,value=['FB'],
                             style={"display": "block", "margin-left": "auto", 
                                    "margin-right": "auto", "width": "60%"}),
                dcc.Graph(id='highlow'),
                html.H1("Facebook Market Volume", style={'textAlign': 'center'}),
         
                dcc.Dropdown(id='my-dropdown2',
                             options=[{'label': 'Tesla', 'value': 'TSLA'},
                                      {'label': 'Apple','value': 'AAPL'}, 
                                      {'label': 'Facebook', 'value': 'FB'},
                                      {'label': 'Microsoft','value': 'MSFT'}], 
                             multi=True,value=['FB'],
                             style={"display": "block", "margin-left": "auto", 
                                    "margin-right": "auto", "width": "60%"}),
                dcc.Graph(id='volume')
            ], className="container"),
        ])
    ])
])
@app.callback(Output('highlow', 'figure'),
              [Input('my-dropdown', 'value')])
def update_graph(selected_dropdown):
    dropdown = {"TSLA": "Tesla","AAPL": "Apple","FB": "Facebook","MSFT": "Microsoft",}
    trace1 = []
    trace2 = []
    for stock in selected_dropdown:
        trace1.append(
          go.Scatter(x=df[df["Stock"] == stock]["Date"],
                     y=df[df["Stock"] == stock]["High"],
                     mode='lines', opacity=0.7, 
                     name=f'High {dropdown[stock]}',textposition='bottom center'))
        trace2.append(
          go.Scatter(x=df[df["Stock"] == stock]["Date"],
                     y=df[df["Stock"] == stock]["Low"],
                     mode='lines', opacity=0.6,
                     name=f'Low {dropdown[stock]}',textposition='bottom center'))
    traces = [trace1, trace2]
    data = [val for sublist in traces for val in sublist]
    figure = {'data': data,
              'layout': go.Layout(colorway=["#5E0DAC", '#FF4F00', '#375CB1', 
                                            '#FF7400', '#FFF400', '#FF0056'],
            height=600,
            title=f"High and Low Prices for {', '.join(str(dropdown[i]) for i in selected_dropdown)} Over Time",
            xaxis={"title":"Date",
                   'rangeselector': {'buttons': list([{'count': 1, 'label': '1M', 
                                                       'step': 'month', 
                                                       'stepmode': 'backward'},
                                                      {'count': 6, 'label': '6M', 
                                                       'step': 'month', 
                                                       'stepmode': 'backward'},
                                                      {'step': 'all'}])},
                   'rangeslider': {'visible': True}, 'type': 'date'},
             yaxis={"title":"Price (USD)"})}
    return figure
@app.callback(Output('volume', 'figure'),
              [Input('my-dropdown2', 'value')])
def update_graph(selected_dropdown_value):
    dropdown = {"TSLA": "Tesla","AAPL": "Apple","FB": "Facebook","MSFT": "Microsoft",}
    trace1 = []
    for stock in selected_dropdown_value:
        trace1.append(
          go.Scatter(x=df[df["Stock"] == stock]["Date"],
                     y=df[df["Stock"] == stock]["Volume"],
                     mode='lines', opacity=0.7,
                     name=f'Volume {dropdown[stock]}', textposition='bottom center'))
    traces = [trace1]
    data = [val for sublist in traces for val in sublist]
    figure = {'data': data, 
              'layout': go.Layout(colorway=["#5E0DAC", '#FF4F00', '#375CB1', 
                                            '#FF7400', '#FFF400', '#FF0056'],
            height=600,
            title=f"Market Volume for {', '.join(str(dropdown[i]) for i in selected_dropdown_value)} Over Time",
            xaxis={"title":"Date",
                   'rangeselector': {'buttons': list([{'count': 1, 'label': '1M', 
                                                       'step': 'month', 
                                                       'stepmode': 'backward'},
                                                      {'count': 6, 'label': '6M',
                                                       'step': 'month', 
                                                       'stepmode': 'backward'},
                                                      {'step': 'all'}])},
                   'rangeslider': {'visible': True}, 'type': 'date'},
             yaxis={"title":"Transactions Volume"})}
    return figure
if __name__=='__main__':
    app.run_server(debug=True)
# Out:
# <ipython-input-1-af42c980282a>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['Predictions']=closing_price
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: on
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3351: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
