# %%
pip install jupyter_plotly_dash
# Out:
# Collecting jupyter_plotly_dash
#   Downloading jupyter_plotly_dash-0.4.3-py3-none-any.whl (29 kB)
# Collecting django-plotly-dash
#   Downloading django_plotly_dash-2.0.0-py3-none-any.whl (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 1.3 MB/s eta 0:00:00
# Collecting dpd-components
#   Downloading dpd_components-0.1.0.tar.gz (4.3 kB)
#   Preparing metadata (setup.py) ... done
# Collecting dpd-static-support
#   Downloading dpd_static_support-0.0.5-py3-none-any.whl (509 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 509.6/509.6 kB 3.9 MB/s eta 0:00:0000:0100:01
# Collecting django-bootstrap4
#   Downloading django_bootstrap4-22.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: jupyter in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from jupyter_plotly_dash) (1.0.0)
# Collecting aiohttp
#   Downloading aiohttp-3.8.1-cp39-cp39-macosx_11_0_arm64.whl (552 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 552.3/552.3 kB 12.7 MB/s eta 0:00:0000:01
# Collecting nbserverproxy
#   Downloading nbserverproxy-0.8.8-py3-none-any.whl (7.5 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.2-cp39-cp39-macosx_11_0_arm64.whl (29 kB)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Requirement already satisfied: attrs>=17.3.0 in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from aiohttp->jupyter_plotly_dash) (21.4.0)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.0-cp39-cp39-macosx_11_0_arm64.whl (34 kB)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.2-cp39-cp39-macosx_11_0_arm64.whl (118 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.1/118.1 kB 5.0 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from aiohttp->jupyter_plotly_dash) (2.1.0)
# Requirement already satisfied: beautifulsoup4>=4.8.0 in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from django-bootstrap4->jupyter_plotly_dash) (4.11.1)
# Collecting Django>=2.2
#   Downloading Django-4.0.6-py3-none-any.whl (8.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 5.9 MB/s eta 0:00:0000:0100:01m
# Collecting Werkzeug<2.1,>=2.0
#   Downloading Werkzeug-2.0.3-py3-none-any.whl (289 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 289.2/289.2 kB 1.7 MB/s eta 0:00:0000:0100:01
# Collecting channels<3.0
#   Downloading channels-2.4.0-py2.py3-none-any.whl (37 kB)
# Collecting dash-bootstrap-components<1
#   Downloading dash_bootstrap_components-0.13.1-py3-none-any.whl (197 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 197.3/197.3 kB 1.7 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: Flask>=1.0.2 in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from django-plotly-dash->jupyter_plotly_dash) (2.1.3)
# Collecting dash>=2.0
#   Downloading dash-2.6.0-py3-none-any.whl (9.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.8/9.8 MB 2.5 MB/s eta 0:00:0000:0100:01
# Collecting Django>=2.2
#   Downloading Django-3.2.14-py3-none-any.whl (7.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 3.4 MB/s eta 0:00:0000:0100:01
# Collecting plotly
#   Downloading plotly-5.9.0-py2.py3-none-any.whl (15.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.2/15.2 MB 4.4 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: nbconvert in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from jupyter->jupyter_plotly_dash) (6.5.0)
# Collecting qtconsole
#   Downloading qtconsole-5.3.1-py3-none-any.whl (120 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.8/120.8 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: ipywidgets in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from jupyter->jupyter_plotly_dash) (7.7.1)
# Requirement already satisfied: notebook in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from jupyter->jupyter_plotly_dash) (6.4.12)
# Requirement already satisfied: jupyter-console in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from jupyter->jupyter_plotly_dash) (6.4.4)
# Requirement already satisfied: ipykernel in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from jupyter->jupyter_plotly_dash) (6.15.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from beautifulsoup4>=4.8.0->django-bootstrap4->jupyter_plotly_dash) (2.3.1)
# Collecting asgiref~=3.2
#   Downloading asgiref-3.5.2-py3-none-any.whl (22 kB)
# Collecting daphne~=2.3
#   Downloading daphne-2.5.0-py2.py3-none-any.whl (26 kB)
# Collecting dash-table==5.0.0
#   Downloading dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Collecting dash-html-components==2.0.0
#   Downloading dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Collecting flask-compress
#   Downloading Flask_Compress-1.12-py3-none-any.whl (7.9 kB)
# Collecting dash-core-components==2.0.0
#   Downloading dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Requirement already satisfied: pytz in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from Django>=2.2->django-bootstrap4->jupyter_plotly_dash) (2022.1)
# Collecting sqlparse>=0.2.2
#   Downloading sqlparse-0.4.2-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 6.8 MB/s eta 0:00:00
# Requirement already satisfied: click>=8.0 in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from Flask>=1.0.2->django-plotly-dash->jupyter_plotly_dash) (8.1.3)
# Requirement already satisfied: Jinja2>=3.0 in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from Flask>=1.0.2->django-plotly-dash->jupyter_plotly_dash) (3.1.2)
# Requirement already satisfied: importlib-metadata>=3.6.0 in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from Flask>=1.0.2->django-plotly-dash->jupyter_plotly_dash) (4.11.4)
# Requirement already satisfied: itsdangerous>=2.0 in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from Flask>=1.0.2->django-plotly-dash->jupyter_plotly_dash) (2.1.2)
# Collecting tenacity>=6.2.0
#   Downloading tenacity-8.0.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: idna>=2.0 in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from yarl<2.0,>=1.0->aiohttp->jupyter_plotly_dash) (3.3)
# Requirement already satisfied: appnope in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from ipykernel->jupyter->jupyter_plotly_dash) (0.1.3)
# Requirement already satisfied: packaging in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from ipykernel->jupyter->jupyter_plotly_dash) (21.3)
# Requirement already satisfied: debugpy>=1.0 in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from ipykernel->jupyter->jupyter_plotly_dash) (1.6.0)
# Requirement already satisfied: pyzmq>=17 in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from ipykernel->jupyter->jupyter_plotly_dash) (23.2.0)
# Requirement already satisfied: nest-asyncio in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from ipykernel->jupyter->jupyter_plotly_dash) (1.5.5)
# Requirement already satisfied: psutil in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from ipykernel->jupyter->jupyter_plotly_dash) (5.9.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from ipykernel->jupyter->jupyter_plotly_dash) (7.3.4)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from ipykernel->jupyter->jupyter_plotly_dash) (0.1.3)
# Requirement already satisfied: ipython>=7.23.1 in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from ipykernel->jupyter->jupyter_plotly_dash) (8.4.0)
# Requirement already satisfied: tornado>=6.1 in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from ipykernel->jupyter->jupyter_plotly_dash) (6.2)
# Requirement already satisfied: traitlets>=5.1.0 in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from ipykernel->jupyter->jupyter_plotly_dash) (5.3.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from ipywidgets->jupyter->jupyter_plotly_dash) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from ipywidgets->jupyter->jupyter_plotly_dash) (3.6.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from ipywidgets->jupyter->jupyter_plotly_dash) (1.1.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from jupyter-console->jupyter->jupyter_plotly_dash) (3.0.30)
# Requirement already satisfied: pygments in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from jupyter-console->jupyter->jupyter_plotly_dash) (2.12.0)
# Requirement already satisfied: jupyter-core>=4.7 in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from nbconvert->jupyter->jupyter_plotly_dash) (4.10.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from nbconvert->jupyter->jupyter_plotly_dash) (2.1.1)
# Requirement already satisfied: bleach in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from nbconvert->jupyter->jupyter_plotly_dash) (5.0.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from nbconvert->jupyter->jupyter_plotly_dash) (1.5.0)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from nbconvert->jupyter->jupyter_plotly_dash) (0.6.6)
# Requirement already satisfied: tinycss2 in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from nbconvert->jupyter->jupyter_plotly_dash) (1.1.1)
# Requirement already satisfied: nbformat>=5.1 in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from nbconvert->jupyter->jupyter_plotly_dash) (5.4.0)
# Requirement already satisfied: defusedxml in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from nbconvert->jupyter->jupyter_plotly_dash) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from nbconvert->jupyter->jupyter_plotly_dash) (0.2.2)
# Requirement already satisfied: entrypoints>=0.2.2 in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from nbconvert->jupyter->jupyter_plotly_dash) (0.4)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from nbconvert->jupyter->jupyter_plotly_dash) (0.8.4)
# Requirement already satisfied: Send2Trash>=1.8.0 in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from notebook->jupyter->jupyter_plotly_dash) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from notebook->jupyter->jupyter_plotly_dash) (0.15.0)
# Requirement already satisfied: argon2-cffi in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from notebook->jupyter->jupyter_plotly_dash) (21.3.0)
# Requirement already satisfied: prometheus-client in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from notebook->jupyter->jupyter_plotly_dash) (0.14.1)
# Collecting qtpy>=2.0.1
#   Downloading QtPy-2.1.0-py3-none-any.whl (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.2/68.2 kB 2.1 MB/s eta 0:00:00
# Collecting twisted[tls]>=18.7
#   Downloading Twisted-22.4.0-py3-none-any.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 5.5 MB/s eta 0:00:0000:0100:01
# Collecting autobahn>=0.18
#   Downloading autobahn-22.6.1.tar.gz (467 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 467.4/467.4 kB 5.0 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: zipp>=0.5 in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from importlib-metadata>=3.6.0->Flask>=1.0.2->django-plotly-dash->jupyter_plotly_dash) (3.8.0)
# Requirement already satisfied: pexpect>4.3 in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->jupyter_plotly_dash) (4.8.0)
# Requirement already satisfied: pickleshare in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->jupyter_plotly_dash) (0.7.5)
# Requirement already satisfied: decorator in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->jupyter_plotly_dash) (5.1.1)
# Requirement already satisfied: stack-data in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->jupyter_plotly_dash) (0.3.0)
# Requirement already satisfied: jedi>=0.16 in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->jupyter_plotly_dash) (0.18.1)
# Requirement already satisfied: setuptools>=18.5 in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->jupyter_plotly_dash) (63.2.0)
# Requirement already satisfied: backcall in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->jupyter_plotly_dash) (0.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter->jupyter_plotly_dash) (2.8.2)
# Requirement already satisfied: fastjsonschema in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from nbformat>=5.1->nbconvert->jupyter->jupyter_plotly_dash) (2.15.3)
# Requirement already satisfied: jsonschema>=2.6 in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from nbformat>=5.1->nbconvert->jupyter->jupyter_plotly_dash) (4.7.2)
# Requirement already satisfied: wcwidth in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->jupyter-console->jupyter->jupyter_plotly_dash) (0.2.5)
# Requirement already satisfied: ptyprocess in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from terminado>=0.8.3->notebook->jupyter->jupyter_plotly_dash) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from argon2-cffi->notebook->jupyter->jupyter_plotly_dash) (21.2.0)
# Requirement already satisfied: webencodings in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from bleach->nbconvert->jupyter->jupyter_plotly_dash) (0.5.1)
# Requirement already satisfied: six>=1.9.0 in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from bleach->nbconvert->jupyter->jupyter_plotly_dash) (1.15.0)
# Collecting brotli
#   Downloading Brotli-1.0.9-cp39-cp39-macosx_10_9_universal2.whl (786 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 786.7/786.7 kB 5.7 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from packaging->ipykernel->jupyter->jupyter_plotly_dash) (3.0.9)
# Collecting txaio>=21.2.1
#   Downloading txaio-22.2.1-py2.py3-none-any.whl (30 kB)
# Requirement already satisfied: cryptography>=3.4.6 in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from autobahn>=0.18->daphne~=2.3->channels<3.0->django-plotly-dash->jupyter_plotly_dash) (37.0.4)
# Collecting hyperlink>=21.0.0
#   Downloading hyperlink-21.0.0-py2.py3-none-any.whl (74 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.6/74.6 kB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter->jupyter_plotly_dash) (0.8.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter->jupyter_plotly_dash) (0.18.1)
# Collecting Automat>=0.8.0
#   Downloading Automat-20.2.0-py2.py3-none-any.whl (31 kB)
# Collecting incremental>=21.3.0
#   Downloading incremental-21.3.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: typing-extensions>=3.6.5 in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from twisted[tls]>=18.7->daphne~=2.3->channels<3.0->django-plotly-dash->jupyter_plotly_dash) (3.7.4.3)
# Collecting constantly>=15.1
#   Downloading constantly-15.1.0-py2.py3-none-any.whl (7.9 kB)
# Collecting zope.interface>=4.4.2
#   Downloading zope.interface-5.4.0.tar.gz (249 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 249.3/249.3 kB 5.0 MB/s eta 0:00:0000:01
#   Preparing metadata (setup.py) ... done
# Collecting service-identity>=18.1.0
#   Downloading service_identity-21.1.0-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: pyopenssl>=16.0.0 in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from twisted[tls]>=18.7->daphne~=2.3->channels<3.0->django-plotly-dash->jupyter_plotly_dash) (22.0.0)
# Requirement already satisfied: cffi>=1.0.1 in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter->jupyter_plotly_dash) (1.15.1)
# Requirement already satisfied: pure-eval in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->jupyter_plotly_dash) (0.2.2)
# Requirement already satisfied: executing in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->jupyter_plotly_dash) (0.8.3)
# Requirement already satisfied: asttokens in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->jupyter_plotly_dash) (2.0.5)
# Requirement already satisfied: pycparser in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter->jupyter_plotly_dash) (2.21)
# Requirement already satisfied: pyasn1-modules in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from service-identity>=18.1.0->twisted[tls]>=18.7->daphne~=2.3->channels<3.0->django-plotly-dash->jupyter_plotly_dash) (0.2.8)
# Requirement already satisfied: pyasn1 in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from service-identity>=18.1.0->twisted[tls]>=18.7->daphne~=2.3->channels<3.0->django-plotly-dash->jupyter_plotly_dash) (0.4.8)
# Building wheels for collected packages: dpd-components, autobahn, zope.interface
#   Building wheel for dpd-components (setup.py) ... done
#   Created wheel for dpd-components: filename=dpd_components-0.1.0-py3-none-any.whl size=4534 sha256=3605770a60407577a6e973cb9f2b9e51affb01fa14c8abb5915c6a51530347fc
#   Stored in directory: /Users/sidd/Library/Caches/pip/wheels/df/0d/a5/30329d8fd0d3aa001680f5b3adefc6ed6d71b5e7350913ff8d
#   Building wheel for autobahn (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [753 lines of output]
#       /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages/setuptools/config/setupcfg.py:463: SetuptoolsDeprecationWarning: The license_file parameter is deprecated, use license_files instead.
#         warnings.warn(msg, warning_class)
#       running bdist_wheel
#       running build
#       running build_py
#       creating build
#       creating build/lib.macosx-11.0-arm64-cpython-39
#       creating build/lib.macosx-11.0-arm64-cpython-39/autobahn
#       copying autobahn/exception.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn
#       copying autobahn/_version.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn
#       copying autobahn/util.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn
#       copying autobahn/__init__.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn
#       copying autobahn/testutil.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn
#       copying autobahn/__main__.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn
#       creating build/lib.macosx-11.0-arm64-cpython-39/autobahn/test
#       copying autobahn/test/test_rng.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/test
#       copying autobahn/test/__init__.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/test
#       copying autobahn/test/test_util.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/test
#       creating build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp
#       copying autobahn/wamp/interfaces.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp
#       copying autobahn/wamp/auth.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp
#       copying autobahn/wamp/exception.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp
#       copying autobahn/wamp/cryptobox.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp
#       copying autobahn/wamp/protocol.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp
#       copying autobahn/wamp/request.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp
#       copying autobahn/wamp/__init__.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp
#       copying autobahn/wamp/message.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp
#       copying autobahn/wamp/types.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp
#       copying autobahn/wamp/role.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp
#       copying autobahn/wamp/message_fbs.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp
#       copying autobahn/wamp/cryptosign.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp
#       copying autobahn/wamp/uri.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp
#       copying autobahn/wamp/serializer.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp
#       copying autobahn/wamp/component.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp
#       copying autobahn/wamp/websocket.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp
#       creating build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/gen
#       copying autobahn/wamp/gen/__init__.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/gen
#       creating build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/gen/wamp
#       copying autobahn/wamp/gen/wamp/Void.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/gen/wamp
#       copying autobahn/wamp/gen/wamp/__init__.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/gen/wamp
#       copying autobahn/wamp/gen/wamp/Map.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/gen/wamp
#       creating build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/gen/wamp/proto
#       copying autobahn/wamp/gen/wamp/proto/Subscribed.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/gen/wamp/proto
#       copying autobahn/wamp/gen/wamp/proto/Hello.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/gen/wamp/proto
#       copying autobahn/wamp/gen/wamp/proto/AuthMode.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/gen/wamp/proto
#       copying autobahn/wamp/gen/wamp/proto/SubscriberReceived.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/gen/wamp/proto
#       copying autobahn/wamp/gen/wamp/proto/Principal.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/gen/wamp/proto
#       copying autobahn/wamp/gen/wamp/proto/Subscribe.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/gen/wamp/proto
#       copying autobahn/wamp/gen/wamp/proto/InvocationPolicy.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/gen/wamp/proto
#       copying autobahn/wamp/gen/wamp/proto/Event.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/gen/wamp/proto
#       copying autobahn/wamp/gen/wamp/proto/AuthMethod.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/gen/wamp/proto
#       copying autobahn/wamp/gen/wamp/proto/EventReceived.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/gen/wamp/proto
#       copying autobahn/wamp/gen/wamp/proto/AuthFactor.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/gen/wamp/proto
#       copying autobahn/wamp/gen/wamp/proto/AuthCryptosignRequest.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/gen/wamp/proto
#       copying autobahn/wamp/gen/wamp/proto/AuthScramWelcome.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/gen/wamp/proto
#       copying autobahn/wamp/gen/wamp/proto/AuthTicketWelcome.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/gen/wamp/proto
#       copying autobahn/wamp/gen/wamp/proto/AuthScramChallenge.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/gen/wamp/proto
#       copying autobahn/wamp/gen/wamp/proto/Error.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/gen/wamp/proto
#       copying autobahn/wamp/gen/wamp/proto/Register.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/gen/wamp/proto
#       copying autobahn/wamp/gen/wamp/proto/MessageType.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/gen/wamp/proto
#       copying autobahn/wamp/gen/wamp/proto/Cancel.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/gen/wamp/proto
#       copying autobahn/wamp/gen/wamp/proto/ClientRoles.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/gen/wamp/proto
#       copying autobahn/wamp/gen/wamp/proto/Unregistered.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/gen/wamp/proto
#       copying autobahn/wamp/gen/wamp/proto/ChannelBinding.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/gen/wamp/proto
#       copying autobahn/wamp/gen/wamp/proto/Interrupt.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/gen/wamp/proto
#       copying autobahn/wamp/gen/wamp/proto/CancelMode.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/gen/wamp/proto
#       copying autobahn/wamp/gen/wamp/proto/CalleeFeatures.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/gen/wamp/proto
#       copying autobahn/wamp/gen/wamp/proto/SubscriberFeatures.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/gen/wamp/proto
#       copying autobahn/wamp/gen/wamp/proto/Abort.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/gen/wamp/proto
#       copying autobahn/wamp/gen/wamp/proto/AuthCraWelcome.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/gen/wamp/proto
#       copying autobahn/wamp/gen/wamp/proto/__init__.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/gen/wamp/proto
#       copying autobahn/wamp/gen/wamp/proto/BrokerFeatures.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/gen/wamp/proto
#       copying autobahn/wamp/gen/wamp/proto/Message.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/gen/wamp/proto
#       copying autobahn/wamp/gen/wamp/proto/AuthTicketChallenge.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/gen/wamp/proto
#       copying autobahn/wamp/gen/wamp/proto/PublisherFeatures.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/gen/wamp/proto
#       copying autobahn/wamp/gen/wamp/proto/AuthCryptosignChallenge.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/gen/wamp/proto
#       copying autobahn/wamp/gen/wamp/proto/AuthScramRequest.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/gen/wamp/proto
#       copying autobahn/wamp/gen/wamp/proto/AuthTicketRequest.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/gen/wamp/proto
#       copying autobahn/wamp/gen/wamp/proto/Payload.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/gen/wamp/proto
#       copying autobahn/wamp/gen/wamp/proto/Result.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/gen/wamp/proto
#       copying autobahn/wamp/gen/wamp/proto/AuthCryptosignWelcome.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/gen/wamp/proto
#       copying autobahn/wamp/gen/wamp/proto/Published.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/gen/wamp/proto
#       copying autobahn/wamp/gen/wamp/proto/Goodbye.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/gen/wamp/proto
#       copying autobahn/wamp/gen/wamp/proto/Unregister.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/gen/wamp/proto
#       copying autobahn/wamp/gen/wamp/proto/HelloNew.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/gen/wamp/proto
#       copying autobahn/wamp/gen/wamp/proto/Unsubscribe.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/gen/wamp/proto
#       copying autobahn/wamp/gen/wamp/proto/AuthCraChallenge.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/gen/wamp/proto
#       copying autobahn/wamp/gen/wamp/proto/Registered.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/gen/wamp/proto
#       copying autobahn/wamp/gen/wamp/proto/Serializer.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/gen/wamp/proto
#       copying autobahn/wamp/gen/wamp/proto/Kdf.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/gen/wamp/proto
#       copying autobahn/wamp/gen/wamp/proto/Yield.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/gen/wamp/proto
#       copying autobahn/wamp/gen/wamp/proto/Invocation.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/gen/wamp/proto
#       copying autobahn/wamp/gen/wamp/proto/RouterRoles.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/gen/wamp/proto
#       copying autobahn/wamp/gen/wamp/proto/Welcome.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/gen/wamp/proto
#       copying autobahn/wamp/gen/wamp/proto/AuthCraRequest.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/gen/wamp/proto
#       copying autobahn/wamp/gen/wamp/proto/Authenticate.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/gen/wamp/proto
#       copying autobahn/wamp/gen/wamp/proto/Call.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/gen/wamp/proto
#       copying autobahn/wamp/gen/wamp/proto/CallerFeatures.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/gen/wamp/proto
#       copying autobahn/wamp/gen/wamp/proto/Challenge.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/gen/wamp/proto
#       copying autobahn/wamp/gen/wamp/proto/Unsubscribed.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/gen/wamp/proto
#       copying autobahn/wamp/gen/wamp/proto/Publish.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/gen/wamp/proto
#       copying autobahn/wamp/gen/wamp/proto/DealerFeatures.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/gen/wamp/proto
#       copying autobahn/wamp/gen/wamp/proto/Match.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/gen/wamp/proto
#       copying autobahn/wamp/gen/wamp/proto/AnyMessage.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/gen/wamp/proto
#       creating build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/test
#       copying autobahn/wamp/test/test_wamp_serializer.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/test
#       copying autobahn/wamp/test/test_wamp_user_handler_errors.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/test
#       copying autobahn/wamp/test/test_wamp_component.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/test
#       copying autobahn/wamp/test/test_wamp_cryptosign.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/test
#       copying autobahn/wamp/test/test_wamp_transport_details.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/test
#       copying autobahn/wamp/test/test_wamp_websocket.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/test
#       copying autobahn/wamp/test/test_wamp_auth.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/test
#       copying autobahn/wamp/test/test_wamp_session_details.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/test
#       copying autobahn/wamp/test/test_wamp_identifiers.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/test
#       copying autobahn/wamp/test/test_wamp_message.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/test
#       copying autobahn/wamp/test/__init__.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/test
#       copying autobahn/wamp/test/test_wamp_scram.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/test
#       copying autobahn/wamp/test/test_wamp_protocol_peer.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/test
#       copying autobahn/wamp/test/test_wamp_component_aio.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/test
#       copying autobahn/wamp/test/test_wamp_exception.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/test
#       copying autobahn/wamp/test/test_wamp_cryptobox.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/test
#       copying autobahn/wamp/test/test_wamp_protocol.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/test
#       copying autobahn/wamp/test/test_wamp_uri_pattern.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/wamp/test
#       creating build/lib.macosx-11.0-arm64-cpython-39/autobahn/websocket
#       copying autobahn/websocket/interfaces.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/websocket
#       copying autobahn/websocket/xormasker.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/websocket
#       copying autobahn/websocket/util.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/websocket
#       copying autobahn/websocket/protocol.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/websocket
#       copying autobahn/websocket/__init__.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/websocket
#       copying autobahn/websocket/types.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/websocket
#       copying autobahn/websocket/compress_base.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/websocket
#       copying autobahn/websocket/compress.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/websocket
#       copying autobahn/websocket/utf8validator.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/websocket
#       copying autobahn/websocket/compress_snappy.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/websocket
#       copying autobahn/websocket/compress_bzip2.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/websocket
#       copying autobahn/websocket/compress_deflate.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/websocket
#       creating build/lib.macosx-11.0-arm64-cpython-39/autobahn/websocket/test
#       copying autobahn/websocket/test/test_websocket_url.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/websocket/test
#       copying autobahn/websocket/test/test_websocket_protocol.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/websocket/test
#       copying autobahn/websocket/test/__init__.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/websocket/test
#       copying autobahn/websocket/test/test_websocket_frame.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/websocket/test
#       creating build/lib.macosx-11.0-arm64-cpython-39/autobahn/rawsocket
#       copying autobahn/rawsocket/util.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/rawsocket
#       copying autobahn/rawsocket/__init__.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/rawsocket
#       creating build/lib.macosx-11.0-arm64-cpython-39/autobahn/rawsocket/test
#       copying autobahn/rawsocket/test/test_rawsocket_url.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/rawsocket/test
#       copying autobahn/rawsocket/test/__init__.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/rawsocket/test
#       creating build/lib.macosx-11.0-arm64-cpython-39/autobahn/asyncio
#       copying autobahn/asyncio/rawsocket.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/asyncio
#       copying autobahn/asyncio/util.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/asyncio
#       copying autobahn/asyncio/__init__.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/asyncio
#       copying autobahn/asyncio/wamp.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/asyncio
#       copying autobahn/asyncio/component.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/asyncio
#       copying autobahn/asyncio/websocket.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/asyncio
#       creating build/lib.macosx-11.0-arm64-cpython-39/autobahn/twisted
#       copying autobahn/twisted/forwarder.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/twisted
#       copying autobahn/twisted/rawsocket.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/twisted
#       copying autobahn/twisted/util.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/twisted
#       copying autobahn/twisted/resource.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/twisted
#       copying autobahn/twisted/__init__.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/twisted
#       copying autobahn/twisted/wamp.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/twisted
#       copying autobahn/twisted/choosereactor.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/twisted
#       copying autobahn/twisted/cryptosign.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/twisted
#       copying autobahn/twisted/component.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/twisted
#       copying autobahn/twisted/websocket.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/twisted
#       creating build/lib.macosx-11.0-arm64-cpython-39/autobahn/twisted/test
#       copying autobahn/twisted/test/test_tx_choosereactor.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/twisted/test
#       copying autobahn/twisted/test/test_wamp_runner.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/twisted/test
#       copying autobahn/twisted/test/test_tx_application_runner.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/twisted/test
#       copying autobahn/twisted/test/__init__.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/twisted/test
#       copying autobahn/twisted/test/test_tx_websocket_agent.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/twisted/test
#       copying autobahn/twisted/test/test_tx_rawsocket.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/twisted/test
#       copying autobahn/twisted/test/test_tx_endpoint_plugins.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/twisted/test
#       copying autobahn/twisted/test/test_tx_protocol.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/twisted/test
#       copying autobahn/twisted/test/test_tx_component.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/twisted/test
#       creating build/lib.macosx-11.0-arm64-cpython-39/autobahn/twisted/testing
#       copying autobahn/twisted/testing/__init__.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/twisted/testing
#       creating build/lib.macosx-11.0-arm64-cpython-39/autobahn/nvx
#       copying autobahn/nvx/_utf8validator.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/nvx
#       copying autobahn/nvx/__init__.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/nvx
#       creating build/lib.macosx-11.0-arm64-cpython-39/autobahn/nvx/test
#       copying autobahn/nvx/test/test_nvx_utf8validator.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/nvx/test
#       copying autobahn/nvx/test/__init__.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/nvx/test
#       creating build/lib.macosx-11.0-arm64-cpython-39/twisted
#       creating build/lib.macosx-11.0-arm64-cpython-39/twisted/plugins
#       copying twisted/plugins/autobahn_endpoints.py -> build/lib.macosx-11.0-arm64-cpython-39/twisted/plugins
#       copying twisted/plugins/autobahn_twistd.py -> build/lib.macosx-11.0-arm64-cpython-39/twisted/plugins
#       creating build/lib.macosx-11.0-arm64-cpython-39/autobahn/xbr
#       copying autobahn/xbr/_schema.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/xbr
#       copying autobahn/xbr/_eip712_member_unregister.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/xbr
#       copying autobahn/xbr/_wallet.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/xbr
#       copying autobahn/xbr/_eip712_market_create.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/xbr
#       copying autobahn/xbr/_gui.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/xbr
#       copying autobahn/xbr/_eip712_node_pair.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/xbr
#       copying autobahn/xbr/_eip712_channel_close.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/xbr
#       copying autobahn/xbr/_eip712_domain_create.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/xbr
#       copying autobahn/xbr/_frealm.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/xbr
#       copying autobahn/xbr/_cli.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/xbr
#       copying autobahn/xbr/_buyer.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/xbr
#       copying autobahn/xbr/_userkey.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/xbr
#       copying autobahn/xbr/_eip712_member_login.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/xbr
#       copying autobahn/xbr/_secmod.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/xbr
#       copying autobahn/xbr/_seller.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/xbr
#       copying autobahn/xbr/__init__.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/xbr
#       copying autobahn/xbr/_interfaces.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/xbr
#       copying autobahn/xbr/_eip712_market_leave.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/xbr
#       copying autobahn/xbr/_abi.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/xbr
#       copying autobahn/xbr/_eip712_consent.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/xbr
#       copying autobahn/xbr/_eip712_catalog_create.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/xbr
#       copying autobahn/xbr/_eip712_api_publish.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/xbr
#       copying autobahn/xbr/_eip712_market_member_login.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/xbr
#       copying autobahn/xbr/_eip712_channel_open.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/xbr
#       copying autobahn/xbr/_eip712_base.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/xbr
#       copying autobahn/xbr/_util.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/xbr
#       copying autobahn/xbr/_mnemonic.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/xbr
#       copying autobahn/xbr/_eip712_market_join.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/xbr
#       copying autobahn/xbr/_dialog.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/xbr
#       copying autobahn/xbr/_config.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/xbr
#       copying autobahn/xbr/_eip712_member_register.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/xbr
#       copying autobahn/xbr/_blockchain.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/xbr
#       creating build/lib.macosx-11.0-arm64-cpython-39/autobahn/xbr/test
#       copying autobahn/xbr/test/test_xbr_schema_demo.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/xbr/test
#       copying autobahn/xbr/test/test_xbr_argon2.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/xbr/test
#       copying autobahn/xbr/test/test_xbr_config.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/xbr/test
#       copying autobahn/xbr/test/__init__.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/xbr/test
#       copying autobahn/xbr/test/test_xbr_schema_wamp.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/xbr/test
#       copying autobahn/xbr/test/test_xbr_schema_wamp_control.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/xbr/test
#       copying autobahn/xbr/test/test_xbr_frealm.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/xbr/test
#       copying autobahn/xbr/test/test_xbr_secmod.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/xbr/test
#       copying autobahn/xbr/test/test_xbr_web3.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/xbr/test
#       copying autobahn/xbr/test/test_xbr_mnemonic.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/xbr/test
#       creating build/lib.macosx-11.0-arm64-cpython-39/autobahn/asyncio/xbr
#       copying autobahn/asyncio/xbr/__init__.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/asyncio/xbr
#       creating build/lib.macosx-11.0-arm64-cpython-39/autobahn/twisted/xbr
#       copying autobahn/twisted/xbr/__init__.py -> build/lib.macosx-11.0-arm64-cpython-39/autobahn/twisted/xbr
#       running egg_info
#       writing autobahn.egg-info/PKG-INFO
#       writing dependency_links to autobahn.egg-info/dependency_links.txt
#       writing entry points to autobahn.egg-info/entry_points.txt
#       writing requirements to autobahn.egg-info/requires.txt
#       writing top-level names to autobahn.egg-info/top_level.txt
#       reading manifest file 'autobahn.egg-info/SOURCES.txt'
#       reading manifest template 'MANIFEST.in'
#       adding license file 'LICENSE'
#       writing manifest file 'autobahn.egg-info/SOURCES.txt'
#       /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages/setuptools/command/build_py.py:153: SetuptoolsDeprecationWarning:     Installing 'autobahn.asset' as data is deprecated, please list it in `packages`.
#           !!
#
#
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'autobahn.asset' as an importable package,
#           but it is not listed in the `packages` configuration of setuptools.
#
#           'autobahn.asset' has been automatically added to the distribution only
#           because it may contain data files, but this behavior is likely to change
#           in future versions of setuptools (and therefore is considered deprecated).
#
#           Please make sure that 'autobahn.asset' is included as a package by using
#           the `packages` configuration field or the proper discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" and "data files" on setuptools
#           documentation page.
#
#
#       !!
#
#         check.warn(importable)
#       /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages/setuptools/command/build_py.py:153: SetuptoolsDeprecationWarning:     Installing 'autobahn.asyncio.test' as data is deprecated, please list it in `packages`.
#           !!
#
#
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'autobahn.asyncio.test' as an importable package,
#           but it is not listed in the `packages` configuration of setuptools.
#
#           'autobahn.asyncio.test' has been automatically added to the distribution only
#           because it may contain data files, but this behavior is likely to change
#           in future versions of setuptools (and therefore is considered deprecated).
#
#           Please make sure that 'autobahn.asyncio.test' is included as a package by using
#           the `packages` configuration field or the proper discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" and "data files" on setuptools
#           documentation page.
#
#
# ...
#       copying src/zope/interface/tests/test_odd_declarations.py -> build/lib.macosx-11.0-arm64-cpython-39/zope/interface/tests
#       copying src/zope/interface/tests/odd.py -> build/lib.macosx-11.0-arm64-cpython-39/zope/interface/tests
#       creating build/lib.macosx-11.0-arm64-cpython-39/zope/interface/common
#       copying src/zope/interface/common/interfaces.py -> build/lib.macosx-11.0-arm64-cpython-39/zope/interface/common
#       copying src/zope/interface/common/builtins.py -> build/lib.macosx-11.0-arm64-cpython-39/zope/interface/common
#       copying src/zope/interface/common/sequence.py -> build/lib.macosx-11.0-arm64-cpython-39/zope/interface/common
#       copying src/zope/interface/common/io.py -> build/lib.macosx-11.0-arm64-cpython-39/zope/interface/common
#       copying src/zope/interface/common/__init__.py -> build/lib.macosx-11.0-arm64-cpython-39/zope/interface/common
#       copying src/zope/interface/common/numbers.py -> build/lib.macosx-11.0-arm64-cpython-39/zope/interface/common
#       copying src/zope/interface/common/idatetime.py -> build/lib.macosx-11.0-arm64-cpython-39/zope/interface/common
#       copying src/zope/interface/common/collections.py -> build/lib.macosx-11.0-arm64-cpython-39/zope/interface/common
#       copying src/zope/interface/common/mapping.py -> build/lib.macosx-11.0-arm64-cpython-39/zope/interface/common
#       creating build/lib.macosx-11.0-arm64-cpython-39/zope/interface/common/tests
#       copying src/zope/interface/common/tests/test_builtins.py -> build/lib.macosx-11.0-arm64-cpython-39/zope/interface/common/tests
#       copying src/zope/interface/common/tests/test_idatetime.py -> build/lib.macosx-11.0-arm64-cpython-39/zope/interface/common/tests
#       copying src/zope/interface/common/tests/basemapping.py -> build/lib.macosx-11.0-arm64-cpython-39/zope/interface/common/tests
#       copying src/zope/interface/common/tests/test_numbers.py -> build/lib.macosx-11.0-arm64-cpython-39/zope/interface/common/tests
#       copying src/zope/interface/common/tests/__init__.py -> build/lib.macosx-11.0-arm64-cpython-39/zope/interface/common/tests
#       copying src/zope/interface/common/tests/test_io.py -> build/lib.macosx-11.0-arm64-cpython-39/zope/interface/common/tests
#       copying src/zope/interface/common/tests/test_import_interfaces.py -> build/lib.macosx-11.0-arm64-cpython-39/zope/interface/common/tests
#       copying src/zope/interface/common/tests/test_collections.py -> build/lib.macosx-11.0-arm64-cpython-39/zope/interface/common/tests
#       running egg_info
#       writing src/zope.interface.egg-info/PKG-INFO
#       writing dependency_links to src/zope.interface.egg-info/dependency_links.txt
#       writing namespace_packages to src/zope.interface.egg-info/namespace_packages.txt
#       writing requirements to src/zope.interface.egg-info/requires.txt
#       writing top-level names to src/zope.interface.egg-info/top_level.txt
#       reading manifest file 'src/zope.interface.egg-info/SOURCES.txt'
#       reading manifest template 'MANIFEST.in'
#       warning: no previously-included files matching '*.dll' found anywhere in distribution
#       warning: no previously-included files matching '*.pyc' found anywhere in distribution
#       warning: no previously-included files matching '*.pyo' found anywhere in distribution
#       warning: no previously-included files matching '*.so' found anywhere in distribution
#       warning: no previously-included files matching 'coverage.xml' found anywhere in distribution
#       warning: no previously-included files matching 'appveyor.yml' found anywhere in distribution
#       no previously-included directories found matching 'docs/_build'
#       no previously-included directories found matching 'benchmarks'
#       adding license file 'LICENSE.txt'
#       writing manifest file 'src/zope.interface.egg-info/SOURCES.txt'
#       copying src/zope/interface/_zope_interface_coptimizations.c -> build/lib.macosx-11.0-arm64-cpython-39/zope/interface
#       running build_ext
#       building 'zope.interface._zope_interface_coptimizations' extension
#       creating build/temp.macosx-11.0-arm64-cpython-39
#       creating build/temp.macosx-11.0-arm64-cpython-39/src
#       creating build/temp.macosx-11.0-arm64-cpython-39/src/zope
#       creating build/temp.macosx-11.0-arm64-cpython-39/src/zope/interface
#       clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/sidd/miniforge3/envs/tensorflow/include -arch arm64 -fPIC -O2 -isystem /Users/sidd/miniforge3/envs/tensorflow/include -arch arm64 -I/Users/sidd/miniforge3/envs/tensorflow/include/python3.9 -c src/zope/interface/_zope_interface_coptimizations.c -o build/temp.macosx-11.0-arm64-cpython-39/src/zope/interface/_zope_interface_coptimizations.o
#       clang -bundle -undefined dynamic_lookup -Wl,-rpath,/Users/sidd/miniforge3/envs/tensorflow/lib -L/Users/sidd/miniforge3/envs/tensorflow/lib -Wl,-rpath,/Users/sidd/miniforge3/envs/tensorflow/lib -L/Users/sidd/miniforge3/envs/tensorflow/lib build/temp.macosx-11.0-arm64-cpython-39/src/zope/interface/_zope_interface_coptimizations.o -o build/lib.macosx-11.0-arm64-cpython-39/zope/interface/_zope_interface_coptimizations.cpython-39-darwin.so
#       ld: warning: ignoring file build/temp.macosx-11.0-arm64-cpython-39/src/zope/interface/_zope_interface_coptimizations.o, building for macOS-x86_64 but attempting to link with file built for unknown-arm64
#       /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#         warnings.warn(
#       installing to build/bdist.macosx-11.0-arm64/wheel
#       running install
#       running install_lib
#       Skipping installation of build/bdist.macosx-11.0-arm64/wheel/zope/__init__.py (namespace package)
#       copying zope/interface/interfaces.py -> build/bdist.macosx-11.0-arm64/wheel/zope/interface
#       copying zope/interface/advice.py -> build/bdist.macosx-11.0-arm64/wheel/zope/interface
#       copying zope/interface/_zope_interface_coptimizations.c -> build/bdist.macosx-11.0-arm64/wheel/zope/interface
#       copying zope/interface/_flatten.py -> build/bdist.macosx-11.0-arm64/wheel/zope/interface
#       copying zope/interface/_zope_interface_coptimizations.cpython-39-darwin.so -> build/bdist.macosx-11.0-arm64/wheel/zope/interface
#       copying zope/interface/registry.py -> build/bdist.macosx-11.0-arm64/wheel/zope/interface
#       copying zope/interface/adapter.py -> build/bdist.macosx-11.0-arm64/wheel/zope/interface
#       copying zope/interface/interface.py -> build/bdist.macosx-11.0-arm64/wheel/zope/interface
#       copying zope/interface/__init__.py -> build/bdist.macosx-11.0-arm64/wheel/zope/interface
#       copying zope/interface/ro.py -> build/bdist.macosx-11.0-arm64/wheel/zope/interface
#       copying zope/interface/document.py -> build/bdist.macosx-11.0-arm64/wheel/zope/interface
#       copying zope/interface/exceptions.py -> build/bdist.macosx-11.0-arm64/wheel/zope/interface
#       copying zope/interface/verify.py -> build/bdist.macosx-11.0-arm64/wheel/zope/interface
#       copying zope/interface/_compat.py -> build/bdist.macosx-11.0-arm64/wheel/zope/interface
#       copying zope/interface/declarations.py -> build/bdist.macosx-11.0-arm64/wheel/zope/interface
#       copying zope/interface/tests/test_registry.py -> build/bdist.macosx-11.0-arm64/wheel/zope/interface/tests
#       copying zope/interface/tests/idummy.py -> build/bdist.macosx-11.0-arm64/wheel/zope/interface/tests
#       copying zope/interface/tests/test_declarations.py -> build/bdist.macosx-11.0-arm64/wheel/zope/interface/tests
#       copying zope/interface/tests/test_sorting.py -> build/bdist.macosx-11.0-arm64/wheel/zope/interface/tests
#       copying zope/interface/tests/test_verify.py -> build/bdist.macosx-11.0-arm64/wheel/zope/interface/tests
#       copying zope/interface/tests/test_element.py -> build/bdist.macosx-11.0-arm64/wheel/zope/interface/tests
#       copying zope/interface/tests/test_exceptions.py -> build/bdist.macosx-11.0-arm64/wheel/zope/interface/tests
#       copying zope/interface/tests/__init__.py -> build/bdist.macosx-11.0-arm64/wheel/zope/interface/tests
#       copying zope/interface/tests/test_adapter.py -> build/bdist.macosx-11.0-arm64/wheel/zope/interface/tests
#       copying zope/interface/tests/advisory_testing.py -> build/bdist.macosx-11.0-arm64/wheel/zope/interface/tests
#       copying zope/interface/tests/test_ro.py -> build/bdist.macosx-11.0-arm64/wheel/zope/interface/tests
#       copying zope/interface/tests/test_advice.py -> build/bdist.macosx-11.0-arm64/wheel/zope/interface/tests
#       copying zope/interface/tests/m1.py -> build/bdist.macosx-11.0-arm64/wheel/zope/interface/tests
#       copying zope/interface/tests/test_interfaces.py -> build/bdist.macosx-11.0-arm64/wheel/zope/interface/tests
#       copying zope/interface/tests/test_document.py -> build/bdist.macosx-11.0-arm64/wheel/zope/interface/tests
#       copying zope/interface/tests/dummy.py -> build/bdist.macosx-11.0-arm64/wheel/zope/interface/tests
#       copying zope/interface/tests/test_interface.py -> build/bdist.macosx-11.0-arm64/wheel/zope/interface/tests
#       copying zope/interface/tests/test_odd_declarations.py -> build/bdist.macosx-11.0-arm64/wheel/zope/interface/tests
#       copying zope/interface/tests/odd.py -> build/bdist.macosx-11.0-arm64/wheel/zope/interface/tests
#       copying zope/interface/common/interfaces.py -> build/bdist.macosx-11.0-arm64/wheel/zope/interface/common
#       copying zope/interface/common/builtins.py -> build/bdist.macosx-11.0-arm64/wheel/zope/interface/common
#       copying zope/interface/common/sequence.py -> build/bdist.macosx-11.0-arm64/wheel/zope/interface/common
#       copying zope/interface/common/io.py -> build/bdist.macosx-11.0-arm64/wheel/zope/interface/common
#       copying zope/interface/common/__init__.py -> build/bdist.macosx-11.0-arm64/wheel/zope/interface/common
#       copying zope/interface/common/numbers.py -> build/bdist.macosx-11.0-arm64/wheel/zope/interface/common
#       copying zope/interface/common/idatetime.py -> build/bdist.macosx-11.0-arm64/wheel/zope/interface/common
#       copying zope/interface/common/collections.py -> build/bdist.macosx-11.0-arm64/wheel/zope/interface/common
#       copying zope/interface/common/mapping.py -> build/bdist.macosx-11.0-arm64/wheel/zope/interface/common
#       copying zope/interface/common/tests/test_builtins.py -> build/bdist.macosx-11.0-arm64/wheel/zope/interface/common/tests
#       copying zope/interface/common/tests/test_idatetime.py -> build/bdist.macosx-11.0-arm64/wheel/zope/interface/common/tests
#       copying zope/interface/common/tests/basemapping.py -> build/bdist.macosx-11.0-arm64/wheel/zope/interface/common/tests
#       copying zope/interface/common/tests/test_numbers.py -> build/bdist.macosx-11.0-arm64/wheel/zope/interface/common/tests
#       copying zope/interface/common/tests/__init__.py -> build/bdist.macosx-11.0-arm64/wheel/zope/interface/common/tests
#       copying zope/interface/common/tests/test_io.py -> build/bdist.macosx-11.0-arm64/wheel/zope/interface/common/tests
#       copying zope/interface/common/tests/test_import_interfaces.py -> build/bdist.macosx-11.0-arm64/wheel/zope/interface/common/tests
#       copying zope/interface/common/tests/test_collections.py -> build/bdist.macosx-11.0-arm64/wheel/zope/interface/common/tests
#       running install_egg_info
#       Copying src/zope.interface.egg-info to build/bdist.macosx-11.0-arm64/wheel/zope.interface-5.4.0-py3.9.egg-info
#       Installing build/bdist.macosx-11.0-arm64/wheel/zope.interface-5.4.0-py3.9-nspkg.pth
#       running install_scripts
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "/private/var/folders/tj/5cwy364j06xcll36yh15qx4h0000gn/T/pip-install-5ckvcr2o/zope-interface_cebbbf2ebbbc43e2b6af5b851a565a49/setup.py", line 102, in <module>
#           setup(name='zope.interface',
#         File "/Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages/setuptools/__init__.py", line 87, in setup
#           return distutils.core.setup(**attrs)
#         File "/Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages/setuptools/_distutils/core.py", line 177, in setup
#           return run_commands(dist)
#         File "/Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages/setuptools/_distutils/core.py", line 193, in run_commands
#           dist.run_commands()
#         File "/Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages/setuptools/_distutils/dist.py", line 968, in run_commands
#           self.run_command(cmd)
#         File "/Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages/setuptools/dist.py", line 1217, in run_command
#           super().run_command(command)
#         File "/Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages/setuptools/_distutils/dist.py", line 987, in run_command
#           cmd_obj.run()
#         File "/Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages/wheel/bdist_wheel.py", line 328, in run
#           impl_tag, abi_tag, plat_tag = self.get_tag()
#         File "/Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages/wheel/bdist_wheel.py", line 278, in get_tag
#           assert tag in supported_tags, "would build wheel with unsupported tag {}".format(tag)
#       AssertionError: would build wheel with unsupported tag ('cp39', 'cp39', 'macosx_11_0_arm64')
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for zope.interface
#   Running setup.py clean for zope.interface
# Successfully built dpd-components
# Failed to build autobahn zope.interface
# Installing collected packages: incremental, dpd-components, dash-table, dash-html-components, dash-core-components, constantly, brotli, zope.interface, Werkzeug, txaio, tenacity, sqlparse, multidict, hyperlink, frozenlist, dpd-static-support, Automat, async-timeout, asgiref, yarl, twisted, qtpy, plotly, Django, aiosignal, service-identity, flask-compress, django-bootstrap4, autobahn, aiohttp, dash, qtconsole, dash-bootstrap-components, daphne, nbserverproxy, channels, django-plotly-dash, jupyter_plotly_dash
#   Running setup.py install for zope.interface ... done
#   DEPRECATION: zope.interface was installed using the legacy 'setup.py install' method, because a wheel could not be built for it. A possible replacement is to fix the wheel build issue reported above. Discussion can be found at https://github.com/pypa/pip/issues/8368
#   Attempting uninstall: Werkzeug
#     Found existing installation: Werkzeug 2.1.2
#     Uninstalling Werkzeug-2.1.2:
#       Successfully uninstalled Werkzeug-2.1.2
#   Running setup.py install for autobahn ... done
#   DEPRECATION: autobahn was installed using the legacy 'setup.py install' method, because a wheel could not be built for it. A possible replacement is to fix the wheel build issue reported above. Discussion can be found at https://github.com/pypa/pip/issues/8368
# Successfully installed Automat-20.2.0 Django-3.2.14 Werkzeug-2.0.3 aiohttp-3.8.1 aiosignal-1.2.0 asgiref-3.5.2 async-timeout-4.0.2 autobahn-22.6.1 brotli-1.0.9 channels-2.4.0 constantly-15.1.0 daphne-2.5.0 dash-2.6.0 dash-bootstrap-components-0.13.1 dash-core-components-2.0.0 dash-html-components-2.0.0 dash-table-5.0.0 django-bootstrap4-22.1 django-plotly-dash-2.0.0 dpd-components-0.1.0 dpd-static-support-0.0.5 flask-compress-1.12 frozenlist-1.3.0 hyperlink-21.0.0 incremental-21.3.0 jupyter_plotly_dash-0.4.3 multidict-6.0.2 nbserverproxy-0.8.8 plotly-5.9.0 qtconsole-5.3.1 qtpy-2.1.0 service-identity-21.1.0 sqlparse-0.4.2 tenacity-8.0.1 twisted-22.4.0 txaio-22.2.1 yarl-1.7.2 zope.interface-5.4.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install dash-html-components
# Out:
# Requirement already satisfied: dash-html-components in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (2.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install dash-core-components
# Out:
# Requirement already satisfied: dash-core-components in /Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages (2.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
import pandas as pd
import plotly.graph_objs as go
from dash.dependencies import Input, Output
from keras.models import load_model
from sklearn.preprocessing import MinMaxScaler
import numpy as np
app = dash.Dash()
server = app.server
scaler=MinMaxScaler(feature_range=(0,1))
df_nse = pd.read_csv("./NSE-TATA.csv")
df_nse["Date"]=pd.to_datetime(df_nse.Date,format="%Y-%m-%d")
df_nse.index=df_nse['Date']
data=df_nse.sort_index(ascending=True,axis=0)
new_data=pd.DataFrame(index=range(0,len(df_nse)),columns=['Date','Close'])
for i in range(0,len(data)):
    new_data["Date"][i]=data['Date'][i]
    new_data["Close"][i]=data["Close"][i]
new_data.index=new_data.Date
new_data.drop("Date",axis=1,inplace=True)
dataset=new_data.values
train=dataset[0:987,:]
valid=dataset[987:,:]
scaler=MinMaxScaler(feature_range=(0,1))
scaled_data=scaler.fit_transform(dataset)
x_train,y_train=[],[]
for i in range(60,len(train)):
    x_train.append(scaled_data[i-60:i,0])
    y_train.append(scaled_data[i,0])
    
x_train,y_train=np.array(x_train),np.array(y_train)
x_train=np.reshape(x_train,(x_train.shape[0],x_train.shape[1],1))
model=load_model("saved_lstm_model.h5")
inputs=new_data[len(new_data)-len(valid)-60:].values
inputs=inputs.reshape(-1,1)
inputs=scaler.transform(inputs)
X_test=[]
for i in range(60,inputs.shape[0]):
    X_test.append(inputs[i-60:i,0])
X_test=np.array(X_test)
X_test=np.reshape(X_test,(X_test.shape[0],X_test.shape[1],1))
closing_price=model.predict(X_test)
closing_price=scaler.inverse_transform(closing_price)
train=new_data[:987]
valid=new_data[987:]
valid['Predictions']=closing_price
df= pd.read_csv("./stock_data.csv")
app.layout = html.Div([
   
    html.H1("Stock Price Analysis Dashboard", style={"textAlign": "center"}),
   
    dcc.Tabs(id="tabs", children=[
       
        dcc.Tab(label='NSE-TATAGLOBAL Stock Data',children=[
            html.Div([
                html.H2("Actual closing price",style={"textAlign": "center"}),
                dcc.Graph(
                    id="Actual Data",
                    figure={
                        "data":[
                            go.Scatter(
                                x=train.index,
                                y=valid["Close"],
                                mode='markers'
                            )
                        ],
                        "layout":go.Layout(
                            title='scatter plot',
                            xaxis={'title':'Date'},
                            yaxis={'title':'Closing Rate'}
                        )
                    }
                ),
                html.H2("LSTM Predicted closing price",style={"textAlign": "center"}),
                dcc.Graph(
                    id="Predicted Data",
                    figure={
                        "data":[
                            go.Scatter(
                                x=valid.index,
                                y=valid["Predictions"],
                                mode='markers'
                            )
                        ],
                        "layout":go.Layout(
                            title='scatter plot',
                            xaxis={'title':'Date'},
                            yaxis={'title':'Closing Rate'}
                        )
                    }
                )                
            ])                
        ]),
        dcc.Tab(label='Facebook Stock Data', children=[
            html.Div([
                html.H1("Facebook Stocks High vs Lows", 
                        style={'textAlign': 'center'}),
              
                dcc.Dropdown(id='my-dropdown',
                             options=[{'label': 'Tesla', 'value': 'TSLA'},
                                      {'label': 'Apple','value': 'AAPL'}, 
                                      {'label': 'Facebook', 'value': 'FB'}, 
                                      {'label': 'Microsoft','value': 'MSFT'}], 
                             multi=True,value=['FB'],
                             style={"display": "block", "margin-left": "auto", 
                                    "margin-right": "auto", "width": "60%"}),
                dcc.Graph(id='highlow'),
                html.H1("Facebook Market Volume", style={'textAlign': 'center'}),
         
                dcc.Dropdown(id='my-dropdown2',
                             options=[{'label': 'Tesla', 'value': 'TSLA'},
                                      {'label': 'Apple','value': 'AAPL'}, 
                                      {'label': 'Facebook', 'value': 'FB'},
                                      {'label': 'Microsoft','value': 'MSFT'}], 
                             multi=True,value=['FB'],
                             style={"display": "block", "margin-left": "auto", 
                                    "margin-right": "auto", "width": "60%"}),
                dcc.Graph(id='volume')
            ], className="container"),
        ])
    ])
])
@app.callback(Output('highlow', 'figure'),
              [Input('my-dropdown', 'value')])
def update_graph(selected_dropdown):
    dropdown = {"TSLA": "Tesla","AAPL": "Apple","FB": "Facebook","MSFT": "Microsoft",}
    trace1 = []
    trace2 = []
    for stock in selected_dropdown:
        trace1.append(
          go.Scatter(x=df[df["Stock"] == stock]["Date"],
                     y=df[df["Stock"] == stock]["High"],
                     mode='lines', opacity=0.7, 
                     name=f'High {dropdown[stock]}',textposition='bottom center'))
        trace2.append(
          go.Scatter(x=df[df["Stock"] == stock]["Date"],
                     y=df[df["Stock"] == stock]["Low"],
                     mode='lines', opacity=0.6,
                     name=f'Low {dropdown[stock]}',textposition='bottom center'))
    traces = [trace1, trace2]
    data = [val for sublist in traces for val in sublist]
    figure = {'data': data,
              'layout': go.Layout(colorway=["#5E0DAC", '#FF4F00', '#375CB1', 
                                            '#FF7400', '#FFF400', '#FF0056'],
            height=600,
            title=f"High and Low Prices for {', '.join(str(dropdown[i]) for i in selected_dropdown)} Over Time",
            xaxis={"title":"Date",
                   'rangeselector': {'buttons': list([{'count': 1, 'label': '1M', 
                                                       'step': 'month', 
                                                       'stepmode': 'backward'},
                                                      {'count': 6, 'label': '6M', 
                                                       'step': 'month', 
                                                       'stepmode': 'backward'},
                                                      {'step': 'all'}])},
                   'rangeslider': {'visible': True}, 'type': 'date'},
             yaxis={"title":"Price (USD)"})}
    return figure
@app.callback(Output('volume', 'figure'),
              [Input('my-dropdown2', 'value')])
def update_graph(selected_dropdown_value):
    dropdown = {"TSLA": "Tesla","AAPL": "Apple","FB": "Facebook","MSFT": "Microsoft",}
    trace1 = []
    for stock in selected_dropdown_value:
        trace1.append(
          go.Scatter(x=df[df["Stock"] == stock]["Date"],
                     y=df[df["Stock"] == stock]["Volume"],
                     mode='lines', opacity=0.7,
                     name=f'Volume {dropdown[stock]}', textposition='bottom center'))
    traces = [trace1]
    data = [val for sublist in traces for val in sublist]
    figure = {'data': data, 
              'layout': go.Layout(colorway=["#5E0DAC", '#FF4F00', '#375CB1', 
                                            '#FF7400', '#FFF400', '#FF0056'],
            height=600,
            title=f"Market Volume for {', '.join(str(dropdown[i]) for i in selected_dropdown_value)} Over Time",
            xaxis={"title":"Date",
                   'rangeselector': {'buttons': list([{'count': 1, 'label': '1M', 
                                                       'step': 'month', 
                                                       'stepmode': 'backward'},
                                                      {'count': 6, 'label': '6M',
                                                       'step': 'month', 
                                                       'stepmode': 'backward'},
                                                      {'step': 'all'}])},
                   'rangeslider': {'visible': True}, 'type': 'date'},
             yaxis={"title":"Transactions Volume"})}
    return figure
if __name__=='__main__':
    app.run_server(debug=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/pkg_resources/__init__.py:3037, in DistInfoDistribution._dep_map(self)
#    3036 try:
# -> 3037     return self.__dep_map
#    3038 except AttributeError:
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/pkg_resources/__init__.py:2834, in Distribution.__getattr__(self, attr)
#    2833 if attr.startswith('_'):
# -> 2834     raise AttributeError(attr)
#    2835 return getattr(self._provider, attr)
#
# AttributeError: _DistInfoDistribution__dep_map
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/pkg_resources/__init__.py:3028, in DistInfoDistribution._parsed_pkg_info(self)
#    3027 try:
# -> 3028     return self._pkg_info
#    3029 except AttributeError:
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/pkg_resources/__init__.py:2834, in Distribution.__getattr__(self, attr)
#    2833 if attr.startswith('_'):
# -> 2834     raise AttributeError(attr)
#    2835 return getattr(self._provider, attr)
#
# AttributeError: _pkg_info
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 import dash
#       2 import dash_core_components as dcc
#       3 import dash_html_components as html
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/dash/__init__.py:36, in <module>
#      29 from .long_callback import (  # noqa: F401,E402
#      30     CeleryManager,
#      31     DiskcacheManager,
#      32 )
#      35 from ._pages import register_page, PAGE_REGISTRY as page_registry  # noqa: F401,E402
# ---> 36 from .dash import (  # noqa: F401,E402
#      37     Dash,
#      38     no_update,
#      39     page_container,
#      40 )
#      43 ctx = callback_context
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/dash/dash.py:73, in <module>
#      66 from . import _pages
#      67 from ._pages import (
#      68     _parse_path_variables,
#      69     _parse_query_string,
#      70 )
# ---> 73 _flask_compress_version = parse_version(get_distribution("flask-compress").version)
#      75 # Add explicit mapping for map files
#      76 mimetypes.add_type("application/json", ".map", True)
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/pkg_resources/__init__.py:478, in get_distribution(dist)
#     476     dist = Requirement.parse(dist)
#     477 if isinstance(dist, Requirement):
# --> 478     dist = get_provider(dist)
#     479 if not isinstance(dist, Distribution):
#     480     raise TypeError("Expected string, Requirement, or Distribution", dist)
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/pkg_resources/__init__.py:354, in get_provider(moduleOrReq)
#     352 """Return an IResourceProvider for the named module or requirement"""
#     353 if isinstance(moduleOrReq, Requirement):
# --> 354     return working_set.find(moduleOrReq) or require(str(moduleOrReq))[0]
#     355 try:
#     356     module = sys.modules[moduleOrReq]
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/pkg_resources/__init__.py:909, in WorkingSet.require(self, *requirements)
#     900 def require(self, *requirements):
#     901     """Ensure that distributions matching `requirements` are activated
#     902
#     903     `requirements` must be a string or a (possibly-nested) sequence
#    (...)
#     907     included, even if they were already activated in this working set.
#     908     """
# --> 909     needed = self.resolve(parse_requirements(requirements))
#     911     for dist in needed:
#     912         self.add(dist)
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/pkg_resources/__init__.py:803, in WorkingSet.resolve(self, requirements, env, installer, replace_conflicting, extras)
#     800     raise VersionConflict(dist, req).with_context(dependent_req)
#     802 # push the new requirements onto the stack
# --> 803 new_requirements = dist.requires(req.extras)[::-1]
#     804 requirements.extend(new_requirements)
#     806 # Register the new requirements needed by req
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/pkg_resources/__init__.py:2755, in Distribution.requires(self, extras)
#    2753 def requires(self, extras=()):
#    2754     """List of Requirements needed for this distro if `extras` are used"""
# -> 2755     dm = self._dep_map
#    2756     deps = []
#    2757     deps.extend(dm.get(None, ()))
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/pkg_resources/__init__.py:3039, in DistInfoDistribution._dep_map(self)
#    3037     return self.__dep_map
#    3038 except AttributeError:
# -> 3039     self.__dep_map = self._compute_dependencies()
#    3040     return self.__dep_map
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/pkg_resources/__init__.py:3048, in DistInfoDistribution._compute_dependencies(self)
#    3046 reqs = []
#    3047 # Including any condition expressions
# -> 3048 for req in self._parsed_pkg_info.get_all('Requires-Dist') or []:
#    3049     reqs.extend(parse_requirements(req))
#    3051 def reqs_for_extra(extra):
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/pkg_resources/__init__.py:3030, in DistInfoDistribution._parsed_pkg_info(self)
#    3028     return self._pkg_info
#    3029 except AttributeError:
# -> 3030     metadata = self.get_metadata(self.PKG_INFO)
#    3031     self._pkg_info = email.parser.Parser().parsestr(metadata)
#    3032     return self._pkg_info
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/pkg_resources/__init__.py:1431, in NullProvider.get_metadata(self, name)
#    1429     return ""
#    1430 path = self._get_metadata_path(name)
# -> 1431 value = self._get(path)
#    1432 try:
#    1433     return value.decode('utf-8')
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/pkg_resources/__init__.py:1635, in DefaultProvider._get(self, path)
#    1634 def _get(self, path):
# -> 1635     with open(path, 'rb') as stream:
#    1636         return stream.read()
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/sidd/miniforge3/envs/tensorflow/lib/python3.9/site-packages/Werkzeug-2.1.2.dist-info/METADATA'
